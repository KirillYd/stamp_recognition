# %% [markdown]
# <a href="https://colab.research.google.com/github/KirillYd/stamp_recognition/blob/text_recognition/%22CRNN_text_recognition2_ipynb%22%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import math
import string

import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import tensorflow as tf
print(tf.__version__)
import tensorflow.keras.backend as K
from tensorflow.keras.backend import get_value, ctc_decode
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Nadam

from google.colab import drive

drive.mount('/content/drive')
# Out:
# 2.17.0
# Mounted at /content/drive

# %% [markdown]
# Data generator

# %%
import os

import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFont

import torch
from torch.utils.data import Dataset, DataLoader

def generate_text(alphabet, seq_len=(2, 20)):
    seq_len = np.random.randint(seq_len[0], seq_len[1]+1)
    text = ''.join([np.random.choice(list(set(alphabet+alphabet.upper()))) for _ in range(seq_len)])

    while len(text.strip()) == 0:
        text = ''.join([np.random.choice(list(set(alphabet+alphabet.upper()))) for _ in range(seq_len)])

    r = np.random.rand()
    if r < 0.2:
        text = text.upper()
    elif r < 0.5:
        text = text.capitalize()
    else:
        text = text.lower()

    return text.strip()

def get_text_dimensions(text_string, font):
    ascent, descent = font.getmetrics()

    text_width = font.getmask(text_string).getbbox()[2]
    text_height = font.getmask(text_string).getbbox()[3] + descent

    return (text_width, text_height)

def safe_convert_to_grayscale(image_to_convert):
    if len(image_to_convert.shape) == 2:
        return image_to_convert
    if len(image_to_convert.shape) == 3:
        if image_to_convert.shape[2] == 1:
            return image_to_convert[:, :, 0]
        if image_to_convert.shape[2] == 3:
            return cv2.cvtColor(image_to_convert, cv2.COLOR_BGR2GRAY)
        if image_to_convert.shape[2] == 4:
            return cv2.cvtColor(image_to_convert, cv2.COLOR_BGRA2GRAY)

    raise ValueError('invalid shape')


def draw_underlined_text(draw, pos, text, font, **options):
    twidth, theight = get_text_dimensions(text, font)
    lx, ly = pos[0], pos[1] + theight

    width = theight // 5

    draw.text(pos, text, font=font, **options)
    draw.line((lx, ly, lx + twidth, ly), width=width, **options)

def draw_overlined_text(draw, pos, text, font, **options):
    twidth, theight = get_text_dimensions(text, font)
    lx, ly = pos[0], pos[1]

    width = theight // 10

    draw.text(pos, text, font=font, **options)
    draw.line((lx, ly, lx + twidth, ly), width=width, **options)


def rotate_image(image, angle):
    if angle == 0:
        return image
    image_center = tuple(np.array(image.shape[1::-1]) / 2)
    rot_mat = cv2.getRotationMatrix2D(image_center, angle, 1.0)

    delta_x = np.ceil(abs(rot_mat[0, 2])).astype(int)
    delta_y = np.ceil(abs(rot_mat[1, 2])).astype(int)

    image = cv2.copyMakeBorder(image, delta_y*2, delta_y*2, delta_x*2, delta_x*2, cv2.BORDER_CONSTANT, value=255)

    result = cv2.warpAffine(image, rot_mat, image.shape[1::-1], flags=cv2.INTER_LINEAR)
    result = result[delta_y: -delta_y, delta_x: -delta_x]
    return result


def add_salt_pepper_noise(image, salt_color, pepper_color, salt_p=0.025, pepper_p=0.025):
    salt_mask = np.random.rand(*image.shape[:2])
    salt_mask[salt_mask < 1-salt_p] = 0
    salt_mask[salt_mask > 0] = 1

    pepper_mask = np.random.rand(*image.shape[:2])
    pepper_mask[pepper_mask < 1-pepper_p] = 0
    pepper_mask[pepper_mask > 0] = 1

    image[salt_mask.astype(bool)] = salt_color
    image[pepper_mask.astype(bool)] = pepper_color

    return image


def prepare_segment_for_recognition(segment, target_shape=(32, 256), pad_value=255):
    segment = safe_convert_to_grayscale(segment)

    coef = min(target_shape[0] / segment.shape[0], target_shape[1] / segment.shape[1])

    segment = cv2.resize(segment, dsize=None, fx=coef, fy=coef, interpolation=cv2.INTER_AREA if coef < 1 else cv2.INTER_CUBIC)
    left = target_shape[1]-segment.shape[1]
    top = target_shape[0]-segment.shape[0]
    segment = cv2.copyMakeBorder(segment, 0, top, 0, left, cv2.BORDER_CONSTANT, value=(pad_value, pad_value, pad_value))

    return segment


def generate_sample(output_shape, alphabet, seq_len, bgs, fonts_path, pad_value):
    font_size = np.random.randint(12, 29)

    font = ImageFont.truetype(os.path.join(fonts_path, np.random.choice(os.listdir(fonts_path))), size=font_size)

    text = generate_text(alphabet, seq_len=seq_len)
    spaces_before = ' '*np.random.randint(0, 3)
    spaces_after = ' '*np.random.randint(0, 3)
    spaced_text = spaces_before + text + spaces_after
    text_w, text_h = get_text_dimensions(spaced_text, font)

    bg = np.full((text_h, text_w), dtype='uint8', fill_value=255)
    bg = Image.fromarray(bg)

    draw = ImageDraw.Draw(bg)

    fill = np.random.randint(0, 31)
    pos = (0, 0)

    r = np.random.random()
    if r < 0.1:
        draw_underlined_text(draw, pos, spaced_text, font, fill=fill)
    elif r < 0.2:
        draw_overlined_text(draw, pos, spaced_text, font, fill=fill)
    else:
        draw.text(pos, spaced_text, fill, font)

    img = np.array(bg)
    img = rotate_image(img, np.random.randint(-2, 3))

    if np.random.random() < 0.1 and img.shape[1] > font_size*2:
        img = img[:, font_size//4: -font_size//4]

    img = img[1:]

    if np.random.random() < 0.5:
        bg = np.full(img.shape[:2], dtype='uint8', fill_value=np.random.randint(230, 256))
    else:
        bg = bgs[np.random.randint(0, len(bgs))]
        if bg.shape[1] > img.shape[1] and bg.shape[0]> img.shape[0]:
            bg_x = np.random.randint(0, bg.shape[1]-img.shape[1]+1)
            bg_y = np.random.randint(0, bg.shape[0]-img.shape[0]+1)
            bg = bg[bg_y: bg_y+img.shape[0], bg_x: bg_x+img.shape[1]]
        else:
            bg = np.full_like(img, fill_value=np.random.randint(230, 256))

    img = np.minimum(img, bg)

    img = add_salt_pepper_noise(img, np.unique(bg)[0], fill)

    img = prepare_segment_for_recognition(img, output_shape, pad_value)

    return img, text.upper()

# %%
class OCRDataset(Dataset):
    def __init__(self, alphabet, output_shape, batch_size, num_steps, fonts_path='/content/drive/MyDrive/text_recognition/Data_gen/fonts', bgs_path='/content/drive/MyDrive/text_recognition/Data_gen/backgrounds'):
        super(Dataset, self).__init__()

        self.alphabet = alphabet
        self.batch_size = batch_size
        self.num_steps = num_steps
        self.output_shape = output_shape
        self.pad_value = 255
        self.fonts_path = fonts_path
        self.bgs = [cv2.imread(f'{bgs_path}/{fn}', cv2.IMREAD_GRAYSCALE) for fn in os.listdir(bgs_path)]

    def encode_text(self, text, seq_len, blank_idx=0):
        def _label_to_num(label):
            label_num = []
            for ch in label:
                idx = self.alphabet.find(ch)
                label_num.append(idx + (idx >= blank_idx))
            return np.array(label_num)

        if blank_idx < 0:
            blank_idx = len(self.alphabet)
        nums = np.full((seq_len,), fill_value=blank_idx, dtype='int32')
        nums[:len(text)] = _label_to_num(text)

        return nums

    def decode_target(self, nums, blank_idx=0):
        if blank_idx < 0:
            blank_idx = len(alphabet)
        nums_collapsed = [self.alphabet[idx-(idx >= blank_idx)] for idx in nums.cpu().detach().numpy() if idx != blank_idx]
        return ''.join(nums_collapsed)

    def decode_pred(self, logits, alphabet_idx, blank_idx=0):
        if blank_idx < 0:
            blank_idx = len(alphabet)
        nums = torch.argmax(logits, dim=-1)
        nums_collapsed = [self.alphabet[idx-(idx >= blank_idx)] for idx, _ in groupby(nums.cpu().detach().numpy()) if idx != blank_idx and idx < len(alphabet)]
        return ''.join(nums_collapsed)

    def __len__(self):
        return self.batch_size * self.num_steps

    def __getitem__(self, idx):
        image, text = generate_sample(output_shape=self.output_shape, alphabet=self.alphabet,
                                      seq_len=(3, 25), bgs=self.bgs, fonts_path=self.fonts_path, pad_value=self.pad_value)

        #image = torch.FloatTensor(image / 255).unsqueeze(0)
        #target = torch.IntTensor(self.encode_text(text, 32))

        return image, text

# %%
def collate_fn(batch):
    images, texts = zip(*batch)  # Распаковываем батч
    return list(images), list(texts)

from torch.utils.data import DataLoader, Dataset, random_split
alphabet = 'ЁАБВГДЕЖЗИЙКЛМНОПРСТУФХЦЧШЩЬЫЪЭЮЯ 0123456789!@№%?()-=+.,/«»:;~"<>[]'
batch_size = 64
num_steps = 100
output_shape=(32, 256)

dataset = OCRDataset(alphabet, output_shape, batch_size, num_steps)

loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn, num_workers= 2)

# %%
for image, text in loader:
  plt.imshow(image[0])
  plt.show()
  plt.imshow(image[0], cmap='gray')
  plt.show()
  break

# %% [markdown]
# # Prepare dataset

# %%
# Data preprocessing

def preprocess(img):
  for func in [resize_n_rotate, add_adaptiveThreshold]:
    img = func(img)
  return img


def resize_n_rotate(img, shape_to=(64, 512)): #shepe_to 64, 800
  if img.shape[0] > shape_to[0] or img.shape[1] > shape_to[1]:
    shrink_multiplayer = min(math.floor(shape_to[0] / img.shape[0] * 100) / 100,
                             math.floor(shape_to[1] / img.shape[1] * 100) / 100)
    img = cv2.resize(img, None,
                     fx=shrink_multiplayer,
                     fy=shrink_multiplayer,
                     interpolation=cv2.INTER_AREA)

  img = cv2.copyMakeBorder(img, math.ceil(shape_to[0]/2) - math.ceil(img.shape[0]/2),
                           math.floor(shape_to[0]/2) - math.floor(img.shape[0]/2),
                           0, #math.ceil(shape_to[1]/2) - math.ceil(img.shape[1]/2)
                           math.floor(shape_to[1]) - math.floor(img.shape[1]), #math.floor(shape_to[1]/2) - math.floor(img.shape[1]/2)
                           cv2.BORDER_CONSTANT, value=255)
  return cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)


def add_adaptiveThreshold(img):
  return cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 21, 10).astype('bool') #THRESH_BINARY_INV


# Label encoding

def encode_text(texts):
  def _label_to_num(label, alphabet):
    label_num = []
    for ch in label:
      label_num.append(alphabet.find(ch))
    return np.array(label_num)

  alphabet = ''.join(sorted(pd.Series(texts).apply(list).apply(pd.Series).stack().unique()))

  nums = np.ones([len(texts), max([len(text) for text in texts])], dtype='int64') * len(alphabet)
  for i, text in enumerate(texts):
    nums[i][:len(text)] = _label_to_num(text, alphabet)

  return nums, alphabet

# %%
#image = np.random.rand(32, 256, 3) * 255  # Случайное цветное изображение
#img = cv2.imread("/content/drive/MyDrive/text_recognition/111.jpg", 0)
#print(img.shape)
#plt.imshow(img)
#plt.show()
#print(type(img))
#image = image.astype(np.uint8)
#print(image)
train_X, train_y = [], []
for image,text in loader:
  for i in range(len(image)):
    train_X.append(preprocess(image[i]))
    train_y.append(text[i])

train_X = np.array(train_X)
train_y, alphabet = encode_text(train_y)
alphabet
# Out:
# ' !"%()+,-./0123456789:;<=>?@[]~«»ЁАБВГДЕЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯ№'

# %%
train_X, val_X, train_y, val_y  = train_test_split(train_X, train_y, test_size=0.2, random_state=42)
train_X, test_X, train_y, test_y  = train_test_split(train_X, train_y, test_size=0.25, random_state=42)

# %%
print("train_X shape:", train_X.shape)  # Ожидается (количество_примеров, 512, 64, 1)
print("train_y shape:", train_y.shape)  # Ожидается (количество_примеров, длина_последовательности)
print("val_X shape:", val_X.shape)      # Ожидается (количество_примеров, 512, 64, 1)
print("val_y shape:", val_y.shape)      # Ожидается (количество_примеров, длина_последовательности)
# Out:
# train_X shape: (3840, 512, 64)
# train_y shape: (3840, 25)
# val_X shape: (1280, 512, 64)
# val_y shape: (1280, 25)

# %%
fig, axes = plt.subplots(figsize=(20, 15), ncols=2, nrows=10)

# Preprocess example

for i in range(10):
  for j in range(2):
    axes[i, j % 2].imshow(cv2.rotate(
        (train_X[i * 2 + j % 2]).astype(np.uint8),cv2.ROTATE_90_COUNTERCLOCKWISE),
        cmap='gray')

# %% [markdown]
# # Model

# %%
class CERMetric(tf.keras.metrics.Metric):
    """
    A custom Keras metric to compute the Character Error Rate
    """
    def __init__(self, name='CER_metric', **kwargs):
        super(CERMetric, self).__init__(name=name, **kwargs)
        self.cer_accumulator = self.add_weight(name="total_cer", initializer="zeros")
        self.counter = self.add_weight(name="cer_count", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        input_shape = K.shape(y_pred)
        input_length = tf.ones(shape=input_shape[0]) * K.cast(input_shape[1], 'float32')

        decode, log = K.ctc_decode(y_pred, input_length, greedy=True)

        decode = K.ctc_label_dense_to_sparse(decode[0], K.cast(input_length, 'int32'))
        y_true_sparse = K.ctc_label_dense_to_sparse(y_true, K.cast(input_length, 'int32'))
        y_true_sparse = tf.sparse.retain(y_true_sparse, tf.not_equal(y_true_sparse.values, tf.math.reduce_max(y_true_sparse.values)))

        decode = tf.sparse.retain(decode, tf.not_equal(decode.values, -1))
        distance = tf.edit_distance(decode, y_true_sparse, normalize=True)

        self.cer_accumulator.assign_add(tf.reduce_sum(distance))
        self.counter.assign_add(K.cast(tf.shape(y_true)[0], 'float32'))

    def result(self):
        return tf.math.divide_no_nan(self.cer_accumulator, self.counter)

    def reset_state(self):
        self.cer_accumulator.assign(0.0)
        self.counter.assign(0.0)


def CTCLoss(y_true, y_pred):
    """
    Compute the training-time loss value
    """
    batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
    input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
    label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")

    input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
    label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")

    loss = K.ctc_batch_cost(y_true, y_pred, input_length, label_length)
    return loss

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01), input_shape=(512, 64, 1))) #tf.keras.layers.LeakyReLU
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((1, 2)))

model.add(Conv2D(128, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())

model.add(Conv2D(128, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(256, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((1, 2)))
model.add(BatchNormalization())

model.add(Reshape((-1, 256)))

model.add(Bidirectional(LSTM(128, return_sequences=True)))
model.add(Bidirectional(LSTM(128, return_sequences=True)))

model.add(Dense(len(alphabet) + 1, activation='softmax')) # +1 for ctc blank

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_20 (Conv2D)                   │ (None, 512, 64, 32)         │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_19 (MaxPooling2D)      │ (None, 256, 32, 32)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 256, 32, 64)         │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_20 (MaxPooling2D)      │ (None, 256, 16, 64)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 256, 16, 128)        │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_21 (MaxPooling2D)      │ (None, 128, 8, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 128, 8, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 128, 8, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_22 (MaxPooling2D)      │ (None, 64, 4, 128)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_24 (Conv2D)                   │ (None, 64, 4, 256)          │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_23 (MaxPooling2D)      │ (None, 64, 2, 256)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_9                │ (None, 64, 2, 256)          │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape_3 (Reshape)                  │ (None, 128, 256)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_3 (Bidirectional)      │ (None, 128, 256)            │         394,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_4 (Bidirectional)      │ (None, 128, 256)            │         394,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128, 68)             │          17,476 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,342,916 (5.12 MB)
#  Trainable params: 1,342,148 (5.12 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
model.compile(optimizer=Nadam(learning_rate=0.001, clipnorm=1.0), loss=CTCLoss, metrics=[CERMetric()])

# %% [markdown]
# # Train model

# %%
checkpoint_path = "/content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Создаем колбек контрольной точки
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)


history = model.fit(train_X, train_y, validation_data=(val_X, val_y),
                    epochs=75, batch_size=64,
                    callbacks=[EarlyStopping(patience=10, restore_best_weights=True, monitor='val_CER_metric', mode='min'),
                              ReduceLROnPlateau(factor=0.5, min_lr=1e-5, patience=4, monitor='val_CER_metric'),
                              cp_callback],
                    verbose=1)

model.save('/content/drive/MyDrive/text_recognition/model/crnn5.h5')
# Out:
# Epoch 1/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - CER_metric: 1.0000 - loss: 61.4874
# Epoch 1: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 296ms/step - CER_metric: 1.0000 - loss: 61.4892 - val_CER_metric: 1.0000 - val_loss: 89.4237 - learning_rate: 0.0010
# Epoch 2/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - CER_metric: 1.0000 - loss: 60.0489
# Epoch 2: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 263ms/step - CER_metric: 1.0000 - loss: 60.0294 - val_CER_metric: 1.0000 - val_loss: 103.8593 - learning_rate: 0.0010
# Epoch 3/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - CER_metric: 0.9639 - loss: 50.7118
# Epoch 3: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 277ms/step - CER_metric: 0.9627 - loss: 50.6412 - val_CER_metric: 1.0000 - val_loss: 136.9147 - learning_rate: 0.0010
# Epoch 4/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - CER_metric: 0.6220 - loss: 32.2276
# Epoch 4: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 266ms/step - CER_metric: 0.6210 - loss: 32.1715 - val_CER_metric: 1.0000 - val_loss: 147.7603 - learning_rate: 0.0010
# Epoch 5/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - CER_metric: 0.3877 - loss: 19.2026
# Epoch 5: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 314ms/step - CER_metric: 0.3874 - loss: 19.1882 - val_CER_metric: 1.0000 - val_loss: 134.6501 - learning_rate: 0.0010
# Epoch 6/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - CER_metric: 0.2582 - loss: 12.8857
# Epoch 6: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 266ms/step - CER_metric: 0.2582 - loss: 12.8812 - val_CER_metric: 1.0000 - val_loss: 127.7948 - learning_rate: 5.0000e-04
# Epoch 7/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - CER_metric: 0.1952 - loss: 9.9328
# Epoch 7: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 269ms/step - CER_metric: 0.1952 - loss: 9.9319 - val_CER_metric: 0.9933 - val_loss: 88.8988 - learning_rate: 5.0000e-04
# Epoch 8/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - CER_metric: 0.1506 - loss: 7.8422
# Epoch 8: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 265ms/step - CER_metric: 0.1506 - loss: 7.8417 - val_CER_metric: 0.9353 - val_loss: 63.8474 - learning_rate: 5.0000e-04
# Epoch 9/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - CER_metric: 0.1087 - loss: 6.1086
# Epoch 9: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 276ms/step - CER_metric: 0.1088 - loss: 6.1083 - val_CER_metric: 0.6470 - val_loss: 35.0603 - learning_rate: 5.0000e-04
# Epoch 10/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - CER_metric: 0.0770 - loss: 4.7011
# Epoch 10: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 267ms/step - CER_metric: 0.0771 - loss: 4.7002 - val_CER_metric: 0.4058 - val_loss: 20.1876 - learning_rate: 5.0000e-04
# Epoch 11/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - CER_metric: 0.0492 - loss: 3.4156
# Epoch 11: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 278ms/step - CER_metric: 0.0493 - loss: 3.4170 - val_CER_metric: 0.3313 - val_loss: 16.2533 - learning_rate: 5.0000e-04
# Epoch 12/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - CER_metric: 0.0321 - loss: 2.5101
# Epoch 12: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 267ms/step - CER_metric: 0.0322 - loss: 2.5108 - val_CER_metric: 0.2940 - val_loss: 15.2205 - learning_rate: 5.0000e-04
# Epoch 13/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - CER_metric: 0.0172 - loss: 1.7566
# Epoch 13: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 273ms/step - CER_metric: 0.0173 - loss: 1.7575 - val_CER_metric: 0.2791 - val_loss: 17.3383 - learning_rate: 5.0000e-04
# Epoch 14/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - CER_metric: 0.0103 - loss: 1.2230
# Epoch 14: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 271ms/step - CER_metric: 0.0103 - loss: 1.2241 - val_CER_metric: 0.2812 - val_loss: 15.3651 - learning_rate: 5.0000e-04
# Epoch 15/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - CER_metric: 0.0064 - loss: 0.8904
# Epoch 15: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 285ms/step - CER_metric: 0.0064 - loss: 0.8913 - val_CER_metric: 0.2878 - val_loss: 15.9016 - learning_rate: 5.0000e-04
# Epoch 16/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - CER_metric: 0.0041 - loss: 0.6650
# Epoch 16: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 267ms/step - CER_metric: 0.0041 - loss: 0.6656 - val_CER_metric: 0.2903 - val_loss: 16.7548 - learning_rate: 5.0000e-04
# Epoch 17/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - CER_metric: 0.0037 - loss: 0.5466
# Epoch 17: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 265ms/step - CER_metric: 0.0037 - loss: 0.5470 - val_CER_metric: 0.2882 - val_loss: 16.8955 - learning_rate: 5.0000e-04
# Epoch 18/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - CER_metric: 0.0020 - loss: 0.3673
# Epoch 18: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 265ms/step - CER_metric: 0.0020 - loss: 0.3665 - val_CER_metric: 0.2613 - val_loss: 16.0478 - learning_rate: 2.5000e-04
# Epoch 19/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - CER_metric: 3.5350e-04 - loss: 0.2006
# Epoch 19: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 267ms/step - CER_metric: 3.5489e-04 - loss: 0.2007 - val_CER_metric: 0.2609 - val_loss: 16.2254 - learning_rate: 2.5000e-04
# Epoch 20/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - CER_metric: 5.2958e-04 - loss: 0.1713
# Epoch 20: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 264ms/step - CER_metric: 5.2615e-04 - loss: 0.1711 - val_CER_metric: 0.2636 - val_loss: 16.0198 - learning_rate: 2.5000e-04
# Epoch 21/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - CER_metric: 2.2195e-04 - loss: 0.1169
# Epoch 21: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 274ms/step - CER_metric: 2.2193e-04 - loss: 0.1170 - val_CER_metric: 0.2566 - val_loss: 16.7525 - learning_rate: 2.5000e-04
# Epoch 22/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - CER_metric: 2.0730e-04 - loss: 0.0990
# Epoch 22: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 266ms/step - CER_metric: 2.0706e-04 - loss: 0.0990 - val_CER_metric: 0.2613 - val_loss: 16.5318 - learning_rate: 2.5000e-04
# Epoch 23/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - CER_metric: 1.8980e-04 - loss: 0.0832
# Epoch 23: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 264ms/step - CER_metric: 1.9057e-04 - loss: 0.0832 - val_CER_metric: 0.2590 - val_loss: 16.7538 - learning_rate: 2.5000e-04
# Epoch 24/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - CER_metric: 5.9291e-05 - loss: 0.0643
# Epoch 24: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 268ms/step - CER_metric: 6.0595e-05 - loss: 0.0644 - val_CER_metric: 0.2622 - val_loss: 16.7885 - learning_rate: 2.5000e-04
# Epoch 25/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - CER_metric: 1.0446e-04 - loss: 0.0599
# Epoch 25: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 267ms/step - CER_metric: 1.0548e-04 - loss: 0.0599 - val_CER_metric: 0.2538 - val_loss: 16.7240 - learning_rate: 2.5000e-04
# Epoch 26/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - CER_metric: 1.1121e-04 - loss: 0.0542
# Epoch 26: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 264ms/step - CER_metric: 1.1114e-04 - loss: 0.0542 - val_CER_metric: 0.2557 - val_loss: 16.7077 - learning_rate: 2.5000e-04
# Epoch 27/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - CER_metric: 2.3382e-05 - loss: 0.0443
# Epoch 27: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 264ms/step - CER_metric: 2.4409e-05 - loss: 0.0443 - val_CER_metric: 0.2516 - val_loss: 16.8807 - learning_rate: 2.5000e-04
# Epoch 28/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - CER_metric: 7.7808e-05 - loss: 0.0441
# Epoch 28: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 275ms/step - CER_metric: 7.7886e-05 - loss: 0.0441 - val_CER_metric: 0.2536 - val_loss: 16.9180 - learning_rate: 2.5000e-04
# Epoch 29/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - CER_metric: 6.2016e-05 - loss: 0.0369
# Epoch 29: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 287ms/step - CER_metric: 6.2158e-05 - loss: 0.0369 - val_CER_metric: 0.2529 - val_loss: 16.9164 - learning_rate: 2.5000e-04
# Epoch 30/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - CER_metric: 4.4995e-05 - loss: 0.0344
# Epoch 30: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 265ms/step - CER_metric: 4.5112e-05 - loss: 0.0344 - val_CER_metric: 0.2524 - val_loss: 16.9351 - learning_rate: 2.5000e-04
# Epoch 31/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - CER_metric: 2.2205e-05 - loss: 0.0301
# Epoch 31: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 17s 276ms/step - CER_metric: 2.2694e-05 - loss: 0.0301 - val_CER_metric: 0.2538 - val_loss: 17.0840 - learning_rate: 2.5000e-04
# Epoch 32/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - CER_metric: 4.4995e-05 - loss: 0.0292
# Epoch 32: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 272ms/step - CER_metric: 4.5112e-05 - loss: 0.0292 - val_CER_metric: 0.2530 - val_loss: 17.1747 - learning_rate: 1.2500e-04
# Epoch 33/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - CER_metric: 2.4911e-05 - loss: 0.0266
# Epoch 33: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 266ms/step - CER_metric: 2.5356e-05 - loss: 0.0266 - val_CER_metric: 0.2527 - val_loss: 17.1868 - learning_rate: 1.2500e-04
# Epoch 34/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - CER_metric: 2.6318e-05 - loss: 0.0264
# Epoch 34: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 268ms/step - CER_metric: 2.6741e-05 - loss: 0.0264 - val_CER_metric: 0.2532 - val_loss: 17.1772 - learning_rate: 1.2500e-04
# Epoch 35/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - CER_metric: 2.7765e-05 - loss: 0.0259
# Epoch 35: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 268ms/step - CER_metric: 2.8164e-05 - loss: 0.0259 - val_CER_metric: 0.2532 - val_loss: 17.2541 - learning_rate: 1.2500e-04
# Epoch 36/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - CER_metric: 6.1706e-05 - loss: 0.0257
# Epoch 36: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 277ms/step - CER_metric: 6.1549e-05 - loss: 0.0257 - val_CER_metric: 0.2512 - val_loss: 17.2724 - learning_rate: 6.2500e-05
# Epoch 37/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - CER_metric: 3.3991e-05 - loss: 0.0237
# Epoch 37: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 266ms/step - CER_metric: 3.4287e-05 - loss: 0.0237 - val_CER_metric: 0.2523 - val_loss: 17.2486 - learning_rate: 6.2500e-05
# Epoch 38/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - CER_metric: 2.7765e-05 - loss: 0.0238
# Epoch 38: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 268ms/step - CER_metric: 2.8164e-05 - loss: 0.0238 - val_CER_metric: 0.2522 - val_loss: 17.3383 - learning_rate: 6.2500e-05
# Epoch 39/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - CER_metric: 2.3540e-05 - loss: 0.0235
# Epoch 39: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 277ms/step - CER_metric: 2.4008e-05 - loss: 0.0235 - val_CER_metric: 0.2529 - val_loss: 17.3123 - learning_rate: 6.2500e-05
# Epoch 40/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - CER_metric: 1.7508e-06 - loss: 0.0216
# Epoch 40: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 266ms/step - CER_metric: 2.5759e-06 - loss: 0.0216 - val_CER_metric: 0.2518 - val_loss: 17.3822 - learning_rate: 6.2500e-05
# Epoch 41/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - CER_metric: 7.4391e-05 - loss: 0.0217
# Epoch 41: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 266ms/step - CER_metric: 7.4025e-05 - loss: 0.0217 - val_CER_metric: 0.2530 - val_loss: 17.3337 - learning_rate: 3.1250e-05
# Epoch 42/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - CER_metric: 0.0000e+00 - loss: 0.0215
# Epoch 42: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 266ms/step - CER_metric: 0.0000e+00 - loss: 0.0215 - val_CER_metric: 0.2522 - val_loss: 17.3506 - learning_rate: 3.1250e-05
# Epoch 43/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - CER_metric: 0.0000e+00 - loss: 0.0205
# Epoch 43: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 268ms/step - CER_metric: 0.0000e+00 - loss: 0.0205 - val_CER_metric: 0.2533 - val_loss: 17.3410 - learning_rate: 3.1250e-05
# Epoch 44/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - CER_metric: 0.0000e+00 - loss: 0.0210
# Epoch 44: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 288ms/step - CER_metric: 0.0000e+00 - loss: 0.0210 - val_CER_metric: 0.2515 - val_loss: 17.3996 - learning_rate: 3.1250e-05
# Epoch 45/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - CER_metric: 0.0000e+00 - loss: 0.0207
# Epoch 45: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 267ms/step - CER_metric: 0.0000e+00 - loss: 0.0207 - val_CER_metric: 0.2524 - val_loss: 17.3950 - learning_rate: 1.5625e-05
# Epoch 46/75
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - CER_metric: 0.0000e+00 - loss: 0.0203
# Epoch 46: saving model to /content/drive/MyDrive/text_recognition/checkpoints/cp3.weights.h5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 315ms/step - CER_metric: 0.0000e+00 - loss: 0.0203 - val_CER_metric: 0.2518 - val_loss: 17.3647 - learning_rate: 1.5625e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
fig, axes = plt.subplots(figsize=(12, 6), ncols=2, nrows=1)

axes[0].plot(history.history['loss'], label='loss')
axes[0].plot(history.history['val_loss'], label='val_loss')
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Loss")
axes[0].legend()
axes[1].plot(history.history['CER_metric'], label='CER_metric')
axes[1].plot(history.history['val_CER_metric'], label='val_CER_metric')
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Character Error Rate")
axes[1].legend()

plt.show()

# %%
model.save('./crnn2.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save('/content/drive/MyDrive/text_recognition/model/crnn2.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save('/content/drive/MyDrive/text_recognition/model/crnn2.keras')

# %% [markdown]
# **Загрузка весов модели**

# %%
model.load_weights('/content/drive/MyDrive/text_recognition/checkpoints/cp.weights.h5') #
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'nadam', because it has 2 variables whereas the saved optimizer has 67 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# ## Model training results

# %%
# Test results: (loss, cer)

model.evaluate(test_X, test_y)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - CER_metric: 0.2457 - loss: 16.9814
# [17.00429916381836, 0.25160980224609375]

# %%
# Decode label for single image

def num_to_label(num, alphabet):
    text = ""
    for ch in num:
        if ch == len(alphabet): # ctc blank
          break
        else:
          text += alphabet[ch]
    return text


# Decode labels for softmax matrix

def decode_text(nums):
  values = get_value(
      ctc_decode(nums, input_length=np.ones(nums.shape[0])*nums.shape[1],
                 greedy=True)[0][0])

  texts = []
  for i in range(nums.shape[0]):
    value = values[i]
    texts.append(num_to_label(value[value >= 0], alphabet))
  return texts

# %%
predicts = model.predict(test_X)
predicts = decode_text(predicts)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step

# %%
# Prediction results

fig, axes = plt.subplots(figsize=(30, 60), ncols=2, nrows=32)

test_X = test_X.astype('int')

# Title format: GT - Predict
for i in range(64):
  axes[i // 2, i % 2].imshow(cv2.rotate(
      (test_X[i]).astype(np.uint8),cv2.ROTATE_90_COUNTERCLOCKWISE),
      cmap='gray')
  axes[i // 2, i % 2].set_title(
      f'{num_to_label(test_y[i], alphabet)} - {predicts[i]}')
  axes[i // 2, i % 2].axis("off")

# %%
#predicts = decode_text(pred_img)



img_path = "/content/drive/MyDrive/text_recognition/123.jpg"
img = cv2.imread(img_path, 0)

processed_img = preprocess(img)

input_data = np.array([processed_img])  # Форма теперь (1, 512, 64, 1)

pred_img = model.predict(input_data)
predictions = decode_text(pred_img)

plt.imshow(img, cmap='gray')
plt.title(f'Predicted Text: {predictions[0]}')
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
